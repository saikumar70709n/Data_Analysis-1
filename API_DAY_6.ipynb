# %%
Random fox API

# %%
import requests

# %%
page=requests.get('https://randomfox.ca//floof')
print(page.status_code)
# Out:
# 200

# %%
print(page.text)
# Out:
# {"image":"https:\/\/randomfox.ca\/images\/21.jpg","link":"https:\/\/randomfox.ca\/?i=21"}

# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'5000',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': 'd4744951-5b0a-4737-aa42-dd4a2b96ac4f',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'status': {'timestamp': '2024-02-16T09:51:35.444Z', 'error_code': 0, 'error_message': None, 'elapsed': 1, 'credit_count': 1, 'notice': None}, 'data': [{'id': 1526, 'name': 'ursfoc0pwsi', 'symbol': 'zej60wezb6k', 'slug': '76sbafeof2a', 'cmc_rank': 7462, 'num_market_pairs': 3752, 'circulating_supply': 4271, 'total_supply': 6970, 'max_supply': 1473, 'infinite_supply': None, 'last_updated': '2024-02-16T09:51:35.444Z', 'date_added': '2024-02-16T09:51:35.444Z', 'tags': ['46lp8y3s8ft', 'il66al12t3n', '3p5rjovzckl', '8omhp7nacyp', 'gslftfoau4u', '7327bonpe8s', 'amqgv6sxsve', 'mws7zbovcsa', 'vfw45tkn7ge', 'az9c79wo3fs'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'USD': {'price': 0.7360866283824841, 'volume_24h': 462, 'volume_change_24h': 0.5434425159994447, 'percent_change_1h': 0.09529716924917131, 'percent_change_24h': 0.6368199812650528, 'percent_change_7d': 0.8591987344405541, 'market_cap': 0.645762665958268, 'market_cap_domina
# ...

# %%
import pandas as pd

# %%
norm=pd.json_normalize(data['data'])
norm
# Out:
#      id          name       symbol          slug  cmc_rank  num_market_pairs  \
# 0  1526   ursfoc0pwsi  zej60wezb6k   76sbafeof2a      7462              3752
# 1   418   wgjunn4j2nm  8e7awnmenhd   dwm7bcoknfv      2221              8570
# 2  3299   yilxgabpjsl  epib5l7zsxo    z39v8ppup9      1964              5398
# 3  5577    o3cm7gyqyc  n99nk4zp9y9   x0dwvkc4dce      5134              3557
# 4  8080   1pbuzclyp3c  9o3847u3ss9   eug2n3jg3we      4658              3119
# 5  1588  0k9yvrqw5dsm  mwlxv6mmniq   ne53kzhifri      4537              8407
# 6  4545   3ku85nrjc9i  b4xd9to2smr   x2axncqq8vl      4419               151
# 7   650   jw70jqni7je  eh7s9tlmqnp   56dqeftyg4p      5154              4236
# 8  7098   nskpyq2ehq8  9ftksuwd7ig  100nu199a0rm      2818              5129
# 9  1228   gxj25wa2huj  7s5ldgj6xtn   f6kode3wr6j      9378              1009
#
#    circulating_supply  total_supply  max_supply infinite_supply  ...  \
# ...

# %%
print(norm)
# Out:
#      id          name       symbol          slug  cmc_rank  num_market_pairs  \
# 0  1526   ursfoc0pwsi  zej60wezb6k   76sbafeof2a      7462              3752
# 1   418   wgjunn4j2nm  8e7awnmenhd   dwm7bcoknfv      2221              8570
# 2  3299   yilxgabpjsl  epib5l7zsxo    z39v8ppup9      1964              5398
# 3  5577    o3cm7gyqyc  n99nk4zp9y9   x0dwvkc4dce      5134              3557
# 4  8080   1pbuzclyp3c  9o3847u3ss9   eug2n3jg3we      4658              3119
# 5  1588  0k9yvrqw5dsm  mwlxv6mmniq   ne53kzhifri      4537              8407
# 6  4545   3ku85nrjc9i  b4xd9to2smr   x2axncqq8vl      4419               151
# 7   650   jw70jqni7je  eh7s9tlmqnp   56dqeftyg4p      5154              4236
# 8  7098   nskpyq2ehq8  9ftksuwd7ig  100nu199a0rm      2818              5129
# 9  1228   gxj25wa2huj  7s5ldgj6xtn   f6kode3wr6j      9378              1009
#
#    circulating_supply  total_supply  max_supply infinite_supply  ...  \
# ...

# %% [markdown]
# extracting data from coinmarket cap API:
# program flow:
# 1.GO TO COINMARKET CAP WEBSITE
# 2.go to products-->API and obtain API key
# 3.go to documentation to obtain API codel
# 4.know your code!
# 5.run it in any pythin environment

# %%
#machine learning
-in the machine learning it training a machine on various things is called machine learning
types of mCHINE LEARNING:
