# %% [markdown]
# Pandas:
# - used for data manuplation (Data cleaning,Organizing data)
# - creates data frames from excel,csv,txt,DBs
# - Dataframe (rows and columns readable by Python)
# - Data cleaning by dropping and replacing with mean
# - Visualize the data

# %%
import pandas as pd

# %% [markdown]
# Series

# %%
names=["Jwalitha","Ramya","kusuma"]
index=[40,42,44]
ser1=pd.Series(names,index)

# %%
print(ser1)
# Out:
# 40    Jwalitha
# 42       Ramya
# 44      kusuma
# dtype: object

# %% [markdown]
# Importing files
# - for csv and txt:read_csv("file path")
# - for excel:read_excel("file path")

# %%
df = pd.read_csv("/content/diabetcsv.csv")

# %%
df.head()
# Out:
#    preg  plas  pres  skin  insu  mass   pedi  age            class
# 0     6   148    72    35     0  33.6  0.627   50  tested_positive
# 1     1    85    66    29     0  26.6  0.351   31  tested_negative
# 2     8   183    64     0     0  23.3  0.672   32  tested_positive
# 3     1    89    66    23    94  28.1  0.167   21  tested_negative
# 4     0   137    40    35   168  43.1  2.288   33  tested_positive

# %%
df.tail()
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative

# %%
dft=pd.read_csv("/content/grades.txt",sep=" ")

# %%
dft.head()
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade
# 0     Joe        K   9.8  10.0   9.9    A+
# 1  Rajesh        M   8.9   9.1   9.3     A
# 2  Kissan        V   9.9   9.3   9.2     A
# 3    Mary        N   7.7   8.0   7.1     B
# 4    Jeen        K   9.8   9.1   9.9    A+

# %%
dfe=pd.read_excel("/content/diabetes.xlsx")
dfe.head()
# Out:
#    preg  plas  pres  skin  insu  mass   pedi  age            class
# 0     6   148    72    35     0  33.6  0.627   50  tested_positive
# 1     1    85    66    29     0  26.6  0.351   31  tested_negative
# 2     8   183    64     0     0  23.3  0.672   32  tested_positive
# 3     1    89    66    23    94  28.1  0.167   21  tested_negative
# 4     0   137    40    35   168  43.1  2.288   33  tested_positive

# %%
df.describe()
# Out:
#              preg        plas        pres        skin        insu        mass  \
# count  768.000000  768.000000  768.000000  768.000000  768.000000  768.000000
# mean     3.845052  120.894531   69.105469   20.536458   79.799479   31.992578
# std      3.369578   31.972618   19.355807   15.952218  115.244002    7.884160
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      1.000000   99.000000   62.000000    0.000000    0.000000   27.300000
# 50%      3.000000  117.000000   72.000000   23.000000   30.500000   32.000000
# 75%      6.000000  140.250000   80.000000   32.000000  127.250000   36.600000
# max     17.000000  199.000000  122.000000   99.000000  846.000000   67.100000
#
#              pedi         age
# count  768.000000  768.000000
# mean     0.471876   33.240885
# std      0.331329   11.760232
# min      0.078000   21.000000
# 25%      0.243750   24.000000
# 50%      0.372500   29.000000
# 75%      0.626250   41.000000
# ...

# %%
print(df.shape)  #printing no .of rows and columns
print(df.shape[0]) #printing no of rows
print(df.shape[1])  #printing no.of colomns
# Out:
# (768, 9)
# 768
# 9

# %% [markdown]
# Accessing data
#
# loc - ccepts column names and index
#
# iloc - accepts only index

# %%
print(dft[2:5])
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade
# 2  Kissan        V   9.9   9.3   9.2     A
# 3    Mary        N   7.7   8.0   7.1     B
# 4    Jeen        K   9.8   9.1   9.9    A+

# %%
print(dft.loc[2:5],"Names")  #rows of specified column
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade
# 2  Kissan        V   9.9   9.3   9.2     A
# 3    Mary        N   7.7   8.0   7.1     B
# 4    Jeen        K   9.8   9.1   9.9    A+
# 5     Raj        M   8.9   9.1   9.3     A Names

# %%
print(dft.iloc[2:5,:3]) #iloc [row range,columnb range]=>index
# Out:
#     Names Initials  SEM1
# 2  Kissan        V   9.9
# 3    Mary        N   7.7
# 4    Jeen        K   9.8

# %%
dfn=pd.read_csv("/content/grades_withnulls.csv")

# %%
dfn.head()
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0     Joe        K   9.8  10.0   9.9    A+       1
# 1  Rajesh        M   8.9   9.1   9.3     A       1
# 2  Kissan        V   9.9   9.8  10.0     A       0
# 3    Mary        N   7.7   8.0   NaN     B       0
# 4    Jeen        K   9.8   9.1   9.9    A+       1

# %%
dfn.isnull()
# Out:
#     Names  Initials   SEM1   SEM2   SEM3  Grade  Placed
# 0   False     False  False  False  False  False   False
# 1   False     False  False  False  False  False   False
# 2   False     False  False  False  False  False   False
# 3   False     False  False  False   True  False   False
# 4   False     False  False  False  False  False   False
# 5   False     False  False  False  False  False   False
# 6   False     False  False  False  False  False   False
# 7   False     False  False  False  False  False   False
# 8   False     False   True  False  False  False   False
# 9   False     False   True  False  False  False   False
# 10  False     False   True  False  False  False   False
# 11  False     False  False  False  False  False   False
# 12  False     False  False  False  False  False   False
# 13  False     False  False  False  False  False   False
# 14  False     False  False  False  False  False   False
# 15  False     False  False  False  False  False   False
# ...

# %%
dfn.isnull().sum()  #to view how many nulls we hae per column
# Out:
# Names       0
# Initials    0
# SEM1        3
# SEM2        0
# SEM3        1
# Grade       0
# Placed      0
# dtype: int64

# %%
dfn.isnull().sum().sum()  #to view total nulls
# Out:
# 4

# %%
dfc=dfn.dropna() # dropping all the rows in nulls

# %%
dfc
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
dfc1=dfn.fillna(7)
dfc1
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %% [markdown]
# Cleaning with mean

# %%
m=dfc['SEM3'].mean()
print(m)
# Out:
# 9.015384615384617

# %%
dfc2=dfn.fillna(m)
(dfc2)
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
dropped=dfc2.drop_duplicates()
print(dropped)
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
dfc2.rename(columns={"Grade":"GPA"},inplace = True) #df,rename(column name={old:new})

# %%
dfc2
# Out:
#      Names Initials  SEM1  SEM2  SEM3 GPA  Placed
# 0      Joe        K   9.8  10.0   9.9  A+       1
# 1   Rajesh        M   8.9   9.1   9.3   A       1
# 2   Kissan        V   9.9   9.8  10.0   A       0
# 4     Jeen        K   9.8   9.1   9.9  A+       1
# 5      Raj        M   8.9   9.1   9.3   A       1
# 6   Hassan        V   9.9   9.0   9.2   A       1
# 7     Mari        N   7.7   8.0   7.1   B       1
# 11    Maya        N   7.7   8.0   7.1   B       0
# 12   Jolin        K   9.8   9.1   9.9  A+       1
# 13  Rajesh        M   8.9   9.1   9.3   A       1
# 14    Riya        M   9.3   9.9  10.0   A       1
# 15    Sana        V   9.9   9.3   9.2   A       0
# 16    Mark        N   7.7   8.0   7.0   B       0

# %%
dfc2['Avg_score'] = (dfc2['SEM1']+dfc2['SEM2']+dfc2['SEM3'])/3 #df['new]

# %%
dfc2.head
# Out:
# <bound method NDFrame.head of      Names Initials  SEM1  SEM2  SEM3 GPA  Placed  Avg_score
# 0      Joe        K   9.8  10.0   9.9  A+       1   9.900000
# 1   Rajesh        M   8.9   9.1   9.3   A       1   9.100000
# 2   Kissan        V   9.9   9.8  10.0   A       0   9.900000
# 4     Jeen        K   9.8   9.1   9.9  A+       1   9.600000
# 5      Raj        M   8.9   9.1   9.3   A       1   9.100000
# 6   Hassan        V   9.9   9.0   9.2   A       1   9.366667
# 7     Mari        N   7.7   8.0   7.1   B       1   7.600000
# 11    Maya        N   7.7   8.0   7.1   B       0   7.600000
# 12   Jolin        K   9.8   9.1   9.9  A+       1   9.600000
# 13  Rajesh        M   8.9   9.1   9.3   A       1   9.100000
# 14    Riya        M   9.3   9.9  10.0   A       1   9.733333
# 15    Sana        V   9.9   9.3   9.2   A       0   9.466667
# 16    Mark        N   7.7   8.0   7.0   B       0   7.566667>

# %%
dfc2[['SEM1','SEM2']].plot.line()
# Out:
# <Axes: >

# %%
dfc2.plot.line(subplots=True)
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >], dtype=object)

# %%
import seaborn as sns

# %%
pl=sns.lineplot(x='Names',y='SEM1',data=dfc2)

# %%
sns.relplot(
    data=dfc2,
    x="SEM2",y="SEM1",col="Placed")

# %% [markdown]
# load diabites. csv
# - create a replot with the index in x axis
# - and age in y axis

# %%
dft=pd.read_csv("/content/diabetcsv.csv",)

# %%
print(dft)
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class
# 0       6   148    72    35     0  33.6  0.627   50  tested_positive
# 1       1    85    66    29     0  26.6  0.351   31  tested_negative
# 2       8   183    64     0     0  23.3  0.672   32  tested_positive
# 3       1    89    66    23    94  28.1  0.167   21  tested_negative
# 4       0   137    40    35   168  43.1  2.288   33  tested_positive
# ..    ...   ...   ...   ...   ...   ...    ...  ...              ...
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative
#
# [768 rows x 9 columns]

# %%
dft['index'] = range(0,768)
sns.relplot(
    data=dft,
    x="index",y="age",col="class")

# %% [markdown]
# inbult data sets in seaborn
# - tips
# - dowjones
# - fmri
# - dots
# - healthext
# - dots to load dataset use: load_dataset("ds name")
#
# hue= different color of different category
# style =

# %%
import seaborn as sns
tips=sns.load_dataset("tips")

# %%
tips.head()
tips.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
tips['index'] = range(0,244)
x=input("enter the situation")
sns.relplot(
    data=tips,
    x="total_bill",
    y="tip",
    hue=x,

)
# Out:
# enter the situationday

# %% [markdown]
# palette=["red", "blue","green","black"]

# %%
dowjones=sns.load_dataset("dowjones")

# %%
dowjones.head()
# Out:
#         Date  Price
# 0 1914-12-01  55.00
# 1 1915-01-01  56.55
# 2 1915-02-01  56.00
# 3 1915-03-01  58.30
# 4 1915-04-01  66.45

# %%
sns.lineplot(data=dowjones,x='Date',y='Price')
# Out:
# <Axes: xlabel='Date', ylabel='Price'>

# %%
sns.catplot(data=tips,x="total_bill",y='day')

# %%
sns.catplot(data=tips,x="time",y='total_bill',kind="violin",hue="smoker")

# %% [markdown]
# linear regression
# plot name is linear fit
# (lmplot create a function)
#
# LINEAR SET
#
# 1 plotting the data set
# 2 fitting the line
# 3 prediction

# %%
sns.lmplot(x="total_bill",y="tip",data=tips);

# %% [markdown]
# 4. WEB SCRAPPING
# 4.1 - Loading data from websites
#     - Unstructured in HTML
#     - Convertible in spread sheets /DB
#     - Major websites have their API`s
#     - Extract all the data on partricular sites
#     - Specifies data that a user wants
#
#    Process:
#    URL->
#    HTML code->
#    Elements(CSS/JS)->
#    Scrapes the required data ->
#    Saves it in required format (csv,xlsx,Json)
#
#   APPLICATIONS
#   - Email Marketing
#   - Sentiment Analysis
#   - News Monitering
#   - Market Research
#   - Price Monitoring
